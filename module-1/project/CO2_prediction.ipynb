# %% [markdown]
# **Load the required files and libraries**

# %%
# Load libraries 
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
# Load the data sets  
train = pd.read_csv("Train.csv")
train.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-23.73_28.77_2019_1    -23.73      28.77  2019        1
# 1  ID_-23.73_28.77_2019_2    -23.73      28.77  2019        2
# 2  ID_-23.73_28.77_2019_3    -23.73      28.77  2019        3
# 3  ID_-23.73_28.77_2019_4    -23.73      28.77  2019        4
# 4  ID_-23.73_28.77_2019_5    -23.73      28.77  2019        5
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                  0.000167
# 1                                 -0.000155
# 2                                 -0.000065
# 3                                  0.000152
# 4                                  0.000024
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.713172
# 1                                      0.812910
# 2                                      0.860306
# 3                                      0.422284
# 4                                      1.004578
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                        0.000102
# 1                                       -0.000137
# 2                                       -0.000062
# 3                                        0.000087
# 4                                        0.000028
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.223929                            24.939440  ...
# 1                       0.080281                            16.624162  ...
# 2                       0.161050                           -13.237244  ...
# 3                       0.046504                           -13.534653  ...
# 4                       0.214246                           -13.475718  ...
#
#    Cloud_cloud_top_height  Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0             5566.222019               54826.032616              4606.209995
# 1             3711.511365               68491.753342              3034.461661
# 2             2136.385189               78967.739548              1433.482587
# 3             3841.853018               64592.806769              2878.512917
# 4             1295.688171               86804.025391              1094.665344
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                  19.115282              0.353778
# 1                  12.218664              0.244987
# 2                   6.062737              0.245102
# 3                   6.388233              0.210904
# 4                   9.206252              0.261103
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                   24.951948                  49.053953
# 1                    4.708856                  42.586683
# 2                   76.060628                  34.737544
# 3                   75.912368                  60.294490
# 4                  -13.346079                  50.194493
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle   emission
# 0                 -89.638032                 17.988874  86.051700
# 1                 -89.904314                 22.773246  88.875670
# 2                 -83.595254                 17.437300  91.723114
# 3                 -71.896728                 11.977818  92.883870
# 4                 -77.462082                 24.374270  94.878330
#
# [5 rows x 76 columns]

# %%
test = pd.read_csv("Test.csv")
test.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0  ID_-23.53_27.47_2019_1    -23.53      27.47  2019        1
# 1  ID_-23.53_27.47_2019_2    -23.53      27.47  2019        2
# 2  ID_-23.53_27.47_2019_3    -23.53      27.47  2019        3
# 3  ID_-23.53_27.47_2019_4    -23.53      27.47  2019        4
# 4  ID_-23.53_27.47_2019_5    -23.53      27.47  2019        5
#
#    SulphurDioxide_SO2_column_number_density  \
# 0                                  0.000077
# 1                                  0.000181
# 2                                  0.000059
# 3                                  0.000483
# 4                                  0.000193
#
#    SulphurDioxide_SO2_column_number_density_amf  \
# 0                                      0.454468
# 1                                      0.423171
# 2                                      0.713085
# 3                                      0.434454
# 4                                      0.783044
#
#    SulphurDioxide_SO2_slant_column_number_density  \
# 0                                        0.000034
# 1                                        0.000062
# 2                                        0.000043
# 3                                        0.000171
# 4                                        0.000141
#
#    SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  ...  \
# 0                       0.114291                           -80.286309  ...
# 1                       0.075100                           -17.765690  ...
# 2                       0.114210                            16.725653  ...
# 3                       0.131394                           -22.475340  ...
# 4                       0.161142                             4.750356  ...
#
#    Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# 0              74897.052000             2180.266538
# 1              84222.653521              982.619057
# 2              78922.490786             1582.964934
# 3              61135.919587             3935.419981
# 4              78494.247391             1647.538526
#
#    Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# 0               81287.074479              1562.031017
# 1               90307.650011               927.111222
# 2               85383.151853              1006.778109
# 3               67490.031362              3428.423528
# 4               84478.743043              1122.534093
#
#    Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# 0                  10.734123              0.280660
# 1                   5.250020              0.238933
# 2                   6.819371              0.258681
# 3                   6.233628              0.281542
# 4                  11.810251              0.281564
#
#    Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# 0                  -31.230174                  33.337966
# 1                   66.490898                  58.137794
# 2                   75.923186                  41.336951
# 3                  -11.023230                  60.689869
# 4                  -13.294513                  51.007132
#
#    Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle
# 0                 -93.217261                 23.358251
# 1                 -85.001467                 13.416481
# 2                 -83.267543                 16.273000
# 3                 -77.763718                 22.793961
# 4                 -76.620646                 23.198242
#
# [5 rows x 75 columns]

# %%
submission = pd.read_csv("SampleSubmission.csv")
submission.head()
# Out:
#      ID_LAT_LON_YEAR_WEEK  emission
# 0  ID_-23.53_27.47_2019_1         0
# 1  ID_-23.53_27.47_2019_2         0
# 2  ID_-23.53_27.47_2019_3         0
# 3  ID_-23.53_27.47_2019_4         0
# 4  ID_-23.53_27.47_2019_5         0

# %% [markdown]
# # Explanatory Data Analysis
# ## Data Assessment

# %%
train

# %% [markdown]
# ## Data Wrangling
