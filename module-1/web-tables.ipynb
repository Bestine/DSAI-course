# %%
import pandas as pd

# %% [markdown]
# Install `lxml` package

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_Internet_connection_speeds")
tables
# Out:
# [    0                                                  1
#  0 NaN  This section needs to be updated. Please help ...,
#          Country/Territory  Averagedownloadspeed(Mbit/s)(Ookla)[1]
#  0               Singapore                                  336.45
#  1    United Arab Emirates                                  310.05
#  2               Hong Kong                                  305.71
#  3                  France                                  287.44
#  4                 Iceland                                  281.95
#  ..                    ...                                     ...
#  147              Cameroon                                    9.02
#  148           Afghanistan                                    3.81
#  149          Turkmenistan                                    3.60
#  150                 Syria                                    3.31
#  151                  Cuba                                    3.04
#
#  [152 rows x 2 columns],
# ...

# %%
tables[1]
# Out:
#         Country/Territory  Averagedownloadspeed(Mbit/s)(Ookla)[1]
# 0               Singapore                                  336.45
# 1    United Arab Emirates                                  310.05
# 2               Hong Kong                                  305.71
# 3                  France                                  287.44
# 4                 Iceland                                  281.95
# ..                    ...                                     ...
# 147              Cameroon                                    9.02
# 148           Afghanistan                                    3.81
# 149          Turkmenistan                                    3.60
# 150                 Syria                                    3.31
# 151                  Cuba                                    3.04
#
# [152 rows x 2 columns]
